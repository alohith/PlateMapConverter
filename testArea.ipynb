# %%
import pandas as pd, numpy as np
from string import ascii_uppercase
from itertools import product
testFile = "/Users/dterciano/Desktop/LokeyLabFiles/TargetMol/platemaps/2023-11-16TargetMol_10uMcompound_PMA_Echotransfer.xlsx"

# %%
platemap = pd.read_excel(testFile, sheet_name='noPMAplate')
display(platemap)
# Out:
#     Source_Plate_Name  UCSC_CSC_plate_ID Source_Well  Source_Concentration  \
# 0               HF014                NaN         C23                 0.025
# 1               HF014                NaN         E23                 0.025
# 2               HF014                NaN         F23                 0.025
# 3               HF014                NaN         K23                 0.025
# 4               HF014                NaN         M23                 0.025
# ..                ...                ...         ...                   ...
# 379             HF014                NaN         K21                50.000
# 380             HF014                NaN         K21                50.000
# 381             HF014                NaN         K21                50.000
# 382             HF014                NaN         K21                50.000
# 383             HF014                NaN         NaN                   NaN
#
#     Source_Concentration_Units    Destination_Plate_Name  \
# 0                           mM  2023-11-07_384PhenoPlate
# 1                           mM  2023-11-07_384PhenoPlate
# 2                           mM  2023-11-07_384PhenoPlate
# 3                           mM  2023-11-07_384PhenoPlate
# 4                           mM  2023-11-07_384PhenoPlate
# ..                         ...                       ...
# 379                          %  2023-11-07_384PhenoPlate
# 380                          %  2023-11-07_384PhenoPlate
# 381                          %  2023-11-07_384PhenoPlate
# 382                          %  2023-11-07_384PhenoPlate
# 383                        NaN  2023-11-07_384PhenoPlate
#
#      Destination_Plate_Barcode 384_Well MoleculeID  Human_Readable_Name  \
# 0                          NaN      C14      PMA_P                  NaN
# 1                          NaN      E05      PMA_P                  NaN
# 2                          NaN      F22      PMA_P                  NaN
# 3                          NaN      K11      PMA_P                  NaN
# 4                          NaN      M04      PMA_P                  NaN
# ..                         ...      ...        ...                  ...
# 379                        NaN      O16     DMSO_R                  NaN
# 380                        NaN      O22     DMSO_R                  NaN
# 381                        NaN      P05     DMSO_R                  NaN
# 382                        NaN      P11     DMSO_R                  NaN
# 383                        NaN      A01        NaN                  NaN
#
#      Transfer_Volume_nL  Assay_Volume_ul  Concentration Units  Well_X  Well_Y
# 0                  50.0             25.0            1.0    uM       3      14
# 1                  50.0             25.0            1.0    uM       5       5
# 2                  50.0             25.0            1.0    uM       6      22
# 3                  50.0             25.0            1.0    uM      11      11
# 4                  50.0             25.0            1.0    uM      13       4
# ..                  ...              ...            ...   ...     ...     ...
# 379                50.0             25.0            1.0    uM      15      16
# 380                50.0             25.0            1.0    uM      15      22
# 381                50.0             25.0            1.0    uM      16       5
# 382                50.0             25.0            1.0    uM      16      11
# 383                 NaN              NaN            NaN   NaN       1       1
#
# [384 rows x 16 columns]

# %%
def long2square(df: pd.DataFrame, col: str, index: str):
    currDf = df.set_index(index)
    wellLetter = [i for i in ascii_uppercase[:16]]
    wellNumber = [i for i in range(1,25)]

    plateLayout = pd.DataFrame(0, index=wellLetter, columns=wellNumber, dtype=str)

    for idx, value in currDf[col].items():
        currLetter = idx[0]
        currNumber = int(idx[1:])
        plateLayout.at[currLetter, currNumber] = value

    plateLayout.index.name = 'well_letter'
    plateLayout.columns.name = 'well_number'
    plateLayout.rename(columns=lambda x: str(x).zfill(2), inplace=True)
    return plateLayout

def square2long(df: pd.DataFrame, col: str, index: str):
    well = [''.join([x,y]) for x,y in product(df.index,df.columns)]
    df.rename(columns=lambda x: str(x).zfill(2), inplace=True)
    listLayout = pd.DataFrame(0, index=well, columns=[col], dtype=str)
    listLayout.index.name = index
    
    for idx, row in df.iterrows():
        for col in df.columns:
            listLayout.loc[f'{idx}{col}'] = row[col]

    return listLayout

# %%
layout = long2square(df=platemap, col='MoleculeID', index='384_Well')
display(layout)
square2long(df=layout, col='MoleculeID', index='384_Well')
# Out:
# well_number      01      02      03      04      05      06      07      08  \
# well_letter
# A               NaN    DMSO    DMSO    DMSO    DMSO    DMSO    DMSO    DMSO
# B              DMSO    DMSO  DMSO_R    DMSO    DMSO    DMSO    DMSO    DMSO
# C              DMSO    DMSO    DMSO    DMSO    DMSO    DMSO    DMSO    DMSO
# D              DMSO    DMSO    DMSO    DMSO    DMSO  DMSO_R    DMSO    DMSO
# E            DMSO_R    DMSO    DMSO    DMSO   PMA_P    DMSO    DMSO    DMSO
# F              DMSO    DMSO    DMSO    DMSO    DMSO    DMSO    DMSO    DMSO
# G              DMSO    DMSO    DMSO  DMSO_R    DMSO    DMSO    DMSO    DMSO
# H              DMSO    DMSO    DMSO    DMSO    DMSO    DMSO    DMSO    DMSO
# I              DMSO    DMSO    DMSO    DMSO    DMSO    DMSO  DMSO_R    DMSO
# J              DMSO  DMSO_R    DMSO    DMSO    DMSO    DMSO    DMSO    DMSO
# K              DMSO    DMSO    DMSO    DMSO    DMSO    DMSO    DMSO    DMSO
# L              DMSO    DMSO    DMSO    DMSO  DMSO_R    DMSO    DMSO    DMSO
# M              DMSO    DMSO    DMSO   PMA_P    DMSO    DMSO    DMSO    DMSO
# N              DMSO  DMSO_R    DMSO    DMSO    DMSO    DMSO    DMSO  DMSO_R
# O              DMSO    DMSO    DMSO    DMSO    DMSO    DMSO    DMSO    DMSO
# P              DMSO    DMSO    DMSO    DMSO  DMSO_R    DMSO    DMSO    DMSO
#
# well_number      09      10  ...      15      16      17      18      19  \
# well_letter                  ...
# A              DMSO    DMSO  ...    DMSO    DMSO    DMSO    DMSO    DMSO
# B            DMSO_R    DMSO  ...    DMSO    DMSO    DMSO    DMSO    DMSO
# C              DMSO    DMSO  ...    DMSO    DMSO  DMSO_R    DMSO    DMSO
# D              DMSO    DMSO  ...    DMSO    DMSO    DMSO    DMSO    DMSO
# E              DMSO    DMSO  ...    DMSO    DMSO    DMSO    DMSO    DMSO
# F            DMSO_R    DMSO  ...  DMSO_R    DMSO    DMSO    DMSO    DMSO
# G              DMSO    DMSO  ...    DMSO    DMSO    DMSO    DMSO    DMSO
# H              DMSO    DMSO  ...    DMSO    DMSO    DMSO  DMSO_R    DMSO
# I              DMSO    DMSO  ...    DMSO    DMSO    DMSO    DMSO    DMSO
# J              DMSO    DMSO  ...    DMSO    DMSO    DMSO    DMSO    DMSO
# K              DMSO  DMSO_R  ...    DMSO  DMSO_R    DMSO    DMSO    DMSO
# L              DMSO    DMSO  ...    DMSO    DMSO    DMSO    DMSO    DMSO
# M              DMSO    DMSO  ...    DMSO    DMSO    DMSO    DMSO  DMSO_R
# N              DMSO    DMSO  ...    DMSO    DMSO    DMSO    DMSO   PMA_P
# O              DMSO    DMSO  ...    DMSO  DMSO_R    DMSO    DMSO    DMSO
# P              DMSO    DMSO  ...    DMSO    DMSO    DMSO    DMSO    DMSO
#
# well_number      20      21      22      23             24
# well_letter
# A            DMSO_R    DMSO    DMSO    DMSO           DMSO
# B              DMSO    DMSO    DMSO    DMSO           DMSO
# C              DMSO    DMSO    DMSO  DMSO_R           DMSO
# D              DMSO    DMSO    DMSO    DMSO           DMSO
# E            DMSO_R    DMSO    DMSO    DMSO           DMSO
# F              DMSO    DMSO   PMA_P    DMSO           DMSO
# G              DMSO    DMSO    DMSO  DMSO_R           DMSO
# H              DMSO    DMSO    DMSO    DMSO           DMSO
# I              DMSO    DMSO    DMSO    DMSO           DMSO
# J              DMSO  DMSO_R    DMSO    DMSO           DMSO
# K              DMSO    DMSO    DMSO    DMSO           DMSO
# L              DMSO    DMSO    DMSO    DMSO         DMSO_R
# M              DMSO    DMSO    DMSO    DMSO           DMSO
# N              DMSO    DMSO    DMSO    DMSO           DMSO
# O              DMSO    DMSO  DMSO_R    DMSO           DMSO
# P              DMSO    DMSO    DMSO    DMSO  food_coloring
#
# [16 rows x 24 columns]
#              MoleculeID
# 384_Well
# A01                 NaN
# A02                DMSO
# A03                DMSO
# A04                DMSO
# A05                DMSO
# ...                 ...
# P20                DMSO
# P21                DMSO
# P22                DMSO
# P23                DMSO
# P24       food_coloring
#
# [384 rows x 1 columns]
